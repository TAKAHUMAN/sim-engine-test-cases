# %% [markdown]
# # PK Reproduction
#
# Placeholder notebook for the Mizuno PK reproduction. The audited implementation is in `model/pk_model.py`, `simulation/pk_simulate.py`, and `simulation/pk_validate.py`.
